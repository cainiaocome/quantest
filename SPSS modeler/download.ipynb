# %%
import tushare as ts

df = ts.get_st_classified()
df
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tushare/stock/classifying.py:143: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   df = df.sort('code').reset_index(drop=True)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>code</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>000033</td>
#       <td>*ST新都</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>000037</td>
#       <td>*ST南电A</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>000155</td>
#       <td>*ST川化</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>000403</td>
#       <td>ST生化</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>000408</td>
#       <td>*ST金源</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>000504</td>
#       <td>*ST生物</td>
#     </tr>
#     <tr>
#       <th>6</th>
# ...

# %%
forcast_data = ts.forecast_data(2016,3)
forcast_data
# Out:
# [Getting data:]
# #
# #
# Length mismatch: Expected axis has 12 elements, new values have 6 elements
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>code</th>
#       <th>name</th>
#       <th>type</th>
#       <th>report_date</th>
#       <th>pre_eps</th>
#       <th>range</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>
