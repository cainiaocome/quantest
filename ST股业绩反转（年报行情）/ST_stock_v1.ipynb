# %%
import tushare as ts

# %%
stock_list = ts.get_stock_basics()
stock_list
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>industry</th>
#       <th>area</th>
#       <th>pe</th>
#       <th>outstanding</th>
#       <th>totals</th>
#       <th>totalAssets</th>
#       <th>liquidAssets</th>
#       <th>fixedAssets</th>
#       <th>reserved</th>
#       <th>...</th>
#       <th>bvps</th>
#       <th>pb</th>
#       <th>timeToMarket</th>
#       <th>undp</th>
#       <th>perundp</th>
#       <th>rev</th>
#       <th>profit</th>
#       <th>gpr</th>
#       <th>npr</th>
#       <th>holders</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
stock_list['name_3'] = stock_list.apply(lambda x: x['name'][0:3],axis=1)
stock_list
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>industry</th>
#       <th>area</th>
#       <th>pe</th>
#       <th>outstanding</th>
#       <th>totals</th>
#       <th>totalAssets</th>
#       <th>liquidAssets</th>
#       <th>fixedAssets</th>
#       <th>reserved</th>
#       <th>...</th>
#       <th>pb</th>
#       <th>timeToMarket</th>
#       <th>undp</th>
#       <th>perundp</th>
#       <th>rev</th>
#       <th>profit</th>
#       <th>gpr</th>
#       <th>npr</th>
#       <th>holders</th>
#       <th>name_3</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
ST_list = stock_list[stock_list.name_3 == '*ST']
ST_list
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>industry</th>
#       <th>area</th>
#       <th>pe</th>
#       <th>outstanding</th>
#       <th>totals</th>
#       <th>totalAssets</th>
#       <th>liquidAssets</th>
#       <th>fixedAssets</th>
#       <th>reserved</th>
#       <th>...</th>
#       <th>pb</th>
#       <th>timeToMarket</th>
#       <th>undp</th>
#       <th>perundp</th>
#       <th>rev</th>
#       <th>profit</th>
#       <th>gpr</th>
#       <th>npr</th>
#       <th>holders</th>
#       <th>name_3</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
ST_list.to_csv('/Users/yanghui/Desktop/ST_stock_v1.csv',encoding='GBK')

# %%
xsg = ts.xsg_data(month='04')  #限售股解禁
xsg
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>code</th>
#       <th>name</th>
#       <th>date</th>
#       <th>count</th>
#       <th>ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>000100</td>
#       <td>TCL集团</td>
#       <td>2017-04-30</td>
#       <td>12455.34</td>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>002279</td>
#       <td>久其软件</td>
#       <td>2017-04-30</td>
#       <td>1164.77</td>
#       <td>2.15</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>002280</td>
#       <td>联络互动</td>
#       <td>2017-04-30</td>
#       <td>1379.89</td>
#       <td>0.63</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>300207</td>
#       <td>欣旺达</td>
#       <td>2017-04-30</td>
#       <td>179.75</td>
#       <td>0.14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>300272</td>
#       <td>开能环保</td>
# ...
